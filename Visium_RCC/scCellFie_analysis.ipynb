# %% [markdown]
# # **scCellFie analysis on the Visium RCC dataset**

# %% [markdown]
# ## Imports

# %%
import sccellfie

import scanpy as sc
import squidpy as sq

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

## To avoid warnings
import warnings
warnings.filterwarnings("ignore")

BASE_PATH = "/home/projects/nyosef/oier/Harreman_files/Revision/Visium_RCC"
ADATA_PATH = f"{BASE_PATH}/h5ads"
DATA_PATH = f"{BASE_PATH}/data"
PLOTS_PATH = f"{BASE_PATH}/plots"
# Out:
# /home/projects/nyosef/oier/mambaforge/envs/sccellfie-dev/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/projects/nyosef/oier/mambaforge/envs/sccellfie-dev/lib/python3.10/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/projects/nyosef/oier/mambaforge/envs/sccellfie-dev/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)

# %%
sccellfie.__version__
# Out:
# '0.6.0'

# %%
adata = sc.read_h5ad(f"{ADATA_PATH}/ST_adata.h5ad")

# %%
adata.obs["n_UMIs"] = np.array(adata.layers["counts"].sum(axis=1)).flatten()

# %%
results = sccellfie.run_sccellfie_pipeline(adata,
                                           organism='human',
                                           sccellfie_data_folder=None,
                                           n_counts_col='n_UMIs',
                                           process_by_group=False,
                                           groupby=None,
                                           neighbors_key='neighbors',
                                           n_neighbors=5,
                                           batch_key='sample',
                                           threshold_key='sccellfie_threshold',
                                           smooth_cells=True,
                                           alpha=0.33,
                                           chunk_size=5000,
                                           disable_pbar=False,
                                           save_folder=None,
                                           save_filename=None
                                          )
# Out:
# ==== scCellFie Pipeline: Initializing ====
# Loading scCellFie database for organism: human
#
# ==== scCellFie Pipeline: Processing entire dataset ====
#
# ---- scCellFie Step: Preprocessing data ----
#
# ---- scCellFie Step: Computing neighbors ----
# ---- scCellFie Step: Preparing inputs ----
# Gene names corrected to match database: 22
# Shape of new adata object: (46398, 930)
# Number of GPRs: 787
# Shape of tasks by genes: (218, 930)
# Shape of reactions by genes: (787, 930)
# Shape of tasks by reactions: (218, 787)
#
# ---- scCellFie Step: Smoothing gene expression ----
# Smoothing Expression: 100%|██████████| 10/10 [00:01<00:00,  8.64it/s]
# ---- scCellFie Step: Computing gene scores ----
#
# ---- scCellFie Step: Computing reaction activity ----
# Cell Rxn Activities: 100%|██████████| 46398/46398 [03:03<00:00, 252.94it/s]
# ---- scCellFie Step: Computing metabolic task activity ----
# Removed 0 metabolic tasks with zeros across all cells.
#
# ==== scCellFie Pipeline: Processing completed successfully ====

# %%
results.keys()
# Out:
# dict_keys(['adata', 'gpr_rules', 'task_by_gene', 'rxn_by_gene', 'task_by_rxn', 'rxn_info', 'task_info', 'thresholds', 'organism'])

# %%
sccellfie.io.save_adata(adata=results['adata'], output_directory=ADATA_PATH, filename='Visium_RCC_scCellFie')
# Out:
# /home/projects/nyosef/oier/Harreman_files/Revision/Visium_RCC/h5ads/Visium_RCC_scCellFie.h5ad was correctly saved
# /home/projects/nyosef/oier/Harreman_files/Revision/Visium_RCC/h5ads/Visium_RCC_scCellFie_reactions.h5ad was correctly saved
# /home/projects/nyosef/oier/Harreman_files/Revision/Visium_RCC/h5ads/Visium_RCC_scCellFie_metabolic_tasks.h5ad was correctly saved

# %%
for sample in adata.obs['sample'].unique():
    print(sample)
    sample_adata = adata[adata.obs['sample'] == sample].copy()
    r = sccellfie.spatial.compute_neighbor_distribution(
        sample_adata,
        radius_range=(100, 1000),  # adjust based on your data's scale
        n_points=200,
        spatial_key='spatial'
    )
    sccellfie.plotting.spatial.plot_neighbor_distribution(r)
    plt.show()
# Out:
# J38_T
# Y7_T
# S15_T
# Y12_T
# R_med
# R51_T
# R114_T
# X49_T
# X98_T
# R_cor
# R29_T
# Z43_T
# H46_T
# Y27_T

# %%
"""
Benchmark: Harreman vs scCellFie
=================================
Computes local colocalization scores between metabolic task ligands
and receptor genes for the 5 axes described by the scCellFie authors:

  1. E2 synthesis (from androstenedione)  → ESR1, ESR2
  2. Thromboxane synthesis (from arachidonate) → TBXA2R
  3. GABA synthesis                        → GABRA1, GABRG2
  4. Testosterone synthesis (from androstenedione) → AR
  5. Dopamine synthesis (tyrosine → dopamine) → DRD1–DRD5

Usage
-----
    # In your notebook / script, after running the scCellFie pipeline:
    #
    #   results = sccellfie.run_sccellfie_pipeline(adata, ...)
    #
    # Then:
    #   import benchmark_harreman_sccellfie as bm
    #   adata_updated = bm.build_adata_updated(adata, results)
    #   bm.inspect_task_names(adata_updated)          # confirm task names first
    #   adata_updated = bm.run_colocalization(adata_updated, task_name_map)
    #   bm.summarise(adata_updated)
"""

import re
import warnings
import numpy as np
import pandas as pd
import sccellfie

# %%
# ---------------------------------------------------------------------------
# Step 1 — Merge metabolic task scores into the gene-expression AnnData
# ---------------------------------------------------------------------------

def build_adata_updated(adata, results):
    """
    Transfer metabolic task scores from results.metabolic_tasks into adata
    (which already carries gene expression in .X and spatial coords in
    .obsm['spatial']).

    Parameters
    ----------
    adata : AnnData
        Original object with gene expression + spatial coordinates.
    results : scCellFie pipeline output
        Must expose a .metabolic_tasks AnnData attribute.

    Returns
    -------
    adata_updated : AnnData
        adata extended with metabolic task variables.
    """
    adata_updated = sccellfie.preprocessing.adata_utils.transfer_variables(
        adata_target=adata,
        adata_source=results['adata'].metabolic_tasks,
        var_names=results['adata'].metabolic_tasks.var_names
    )
    print(
        f"adata_updated: {adata_updated.n_obs} cells × {adata_updated.n_vars} vars "
        f"({adata.n_vars} genes + {results['adata'].metabolic_tasks.n_vars} tasks)"
    )
    return adata_updated


# ---------------------------------------------------------------------------
# Step 2 — Inspect task names and map them to the 5 metabolic axes
# ---------------------------------------------------------------------------

# Keywords to search for in var_names (case-insensitive)
SEARCH_TERMS = {
    "E2 / estradiol":    [r"estradiol", r"\be2\b", r"17.?beta"],
    "thromboxane":       [r"thromboxane"],
    "GABA":              [r"\bgaba\b", r"gamma.?aminobutyric"],
    "testosterone":      [r"testosterone"],
    "dopamine":          [r"dopamine", r"tyrosine.*dopamine", r"dopa"],
}


def inspect_task_names(adata_updated):
    """
    Print metabolic task var_names that match each of the 5 axes.
    Review the output and pass the confirmed names to run_colocalization()
    via task_name_map.
    """
    # Separate task vars from gene vars using the 'type' metadata if present,
    # otherwise fall back to all var_names that are not in common gene-name
    # format (all-caps short token).
    if "type" in adata_updated.var.columns:
        task_vars = adata_updated.var_names[
            adata_updated.var["type"] == "metabolic score"
        ].tolist()
    else:
        # heuristic: task names tend to be longer / contain spaces
        task_vars = [v for v in adata_updated.var_names if " " in v or len(v) > 10]

    print("=" * 60)
    print("Metabolic task name inspection")
    print("=" * 60)
    for axis, patterns in SEARCH_TERMS.items():
        matches = []
        for name in task_vars:
            for pat in patterns:
                if re.search(pat, name, re.IGNORECASE):
                    matches.append(name)
                    break
        print(f"\n[{axis}]")
        if matches:
            for m in matches:
                print(f"  ✓  {m!r}")
        else:
            print("  ✗  No matches found — check var_names manually")

    print("\n" + "=" * 60)
    print("All task var_names (for manual inspection):")
    for v in sorted(task_vars):
        print(f"  {v!r}")


# ---------------------------------------------------------------------------
# Step 3 — Define ligand→receptor pairs and run colocalization scoring
# ---------------------------------------------------------------------------

def _default_task_name_map():
    """
    Placeholder task names based on common scCellFie naming conventions.
    Replace values with the exact strings from inspect_task_names().
    """
    return {
        "E2":          "Synthesis of estradiol-17beta (E2) from androstenedione",
        "thromboxane": "Synthesis of thromboxane from arachidonate",
        "GABA":        "Synthesis of GABA",
        "testosterone":"Synthesis of testosterone from androstenedione",
        "dopamine":    "Tyrosine to dopamine",
    }


def _build_pairs(task_name_map):
    """
    Build the list of (obs_col_name, var1, var2_list) tuples.
    """
    tm = task_name_map
    pairs = [
        # (obs column name,   ligand task,         receptor gene(s))
        ("E2__ESR1",          tm["E2"],             ["ESR1"]),
        ("E2__ESR2",          tm["E2"],             ["ESR2"]),
        ("thromboxane__TBXA2R", tm["thromboxane"],  ["TBXA2R"]),
        ("GABA__GABRA1",      tm["GABA"],           ["GABRA1"]),
        ("GABA__GABRG2",      tm["GABA"],           ["GABRG2"]),
        ("testosterone__AR",  tm["testosterone"],   ["AR"]),
        ("dopamine__DRD1",    tm["dopamine"],        ["DRD1"]),
        ("dopamine__DRD2",    tm["dopamine"],        ["DRD2"]),
        ("dopamine__DRD3",    tm["dopamine"],        ["DRD3"]),
        ("dopamine__DRD4",    tm["dopamine"],        ["DRD4"]),
        ("dopamine__DRD5",    tm["dopamine"],        ["DRD5"]),
    ]
    return pairs


def run_colocalization(
    adata_updated,
    task_name_map=None,
    neighbors_radius=100,
    method="pairwise_concordance",
    min_neighbors=3,
    spatial_key="spatial",
):
    """
    Same as before but operates on a single-sample AnnData slice.
    Scores are written into adata_updated.obs and returned as a DataFrame.
    """
    if task_name_map is None:
        warnings.warn(
            "task_name_map not provided — using placeholder task names. "
            "Run inspect_task_names() first and pass confirmed names.",
            UserWarning,
        )
        task_name_map = _default_task_name_map()

    pairs = _build_pairs(task_name_map)

    scored_cols = []
    for obs_col, var1, var2_list in pairs:
        missing = [v for v in [var1] + var2_list if v not in adata_updated.var_names]
        if missing:
            warnings.warn(
                f"Skipping '{obs_col}': variables not found in adata_updated: {missing}"
            )
            continue

        print(f"  Scoring  {obs_col!r}  |  '{var1}'  →  {var2_list} ...", end="  ")
        try:
            scores = sccellfie.communication.compute_local_colocalization_scores(
                adata_updated,
                var1=var1,
                var2=var2_list,
                neighbors_radius=neighbors_radius,
                method=method,
                min_neighbors=min_neighbors,
                spatial_key=spatial_key,
                inplace=False,
            )
            adata_updated.obs[obs_col] = scores
            scored_cols.append(obs_col)
            n_scored = (~np.isnan(scores)).sum() if hasattr(scores, "__len__") else "?"
            print(f"done  ({n_scored} cells scored)")
        except Exception as exc:
            print(f"FAILED — {exc}")

    print(f"  → {len(scored_cols)}/{len(pairs)} pairs scored successfully.")
    results_df = adata_updated.obs[scored_cols].copy()
    return adata_updated, results_df


# ---------------------------------------------------------------------------
# Step 4 — Summarise results
# ---------------------------------------------------------------------------

def summarise(adata_updated, results_df=None):
    """
    Print a summary table of mean colocalization scores per scored pair,
    and report how many cells have a non-NaN score for each pair.
    """
    # Auto-detect scored columns if results_df not provided
    if results_df is None:
        axes = list(_default_task_name_map().keys())
        scored_cols = [
            c for c in adata_updated.obs.columns
            if any(c.startswith(a) for a in
                   ["E2__", "thromboxane__", "GABA__", "testosterone__", "dopamine__"])
        ]
        results_df = adata_updated.obs[scored_cols]

    if results_df.empty:
        print("No scored columns found.")
        return

    summary = pd.DataFrame({
        "n_cells_scored": results_df.notna().sum(),
        "mean_score":     results_df.mean(),
        "median_score":   results_df.median(),
        "std_score":      results_df.std(),
    })
    summary.index.name = "pair"
    summary = summary.sort_values("mean_score", ascending=False)

    print("\n" + "=" * 60)
    print("Colocalization score summary")
    print("=" * 60)
    print(summary.to_string(float_format="{:.4f}".format))
    print("=" * 60)
    return summary


# ---------------------------------------------------------------------------
# Convenience: run everything end-to-end
# ---------------------------------------------------------------------------

def run_benchmark(adata, results, task_name_map, **kwargs):
    """
    End-to-end convenience wrapper.

    Parameters
    ----------
    adata : AnnData
        Gene expression + spatial AnnData.
    results : scCellFie pipeline output
    task_name_map : dict
        Confirmed task names from inspect_task_names().
    **kwargs
        Passed to run_colocalization() (neighbors_radius, method, etc.).

    Returns
    -------
    adata_updated : AnnData
    results_df : pd.DataFrame
    summary : pd.DataFrame
    """
    adata_updated = build_adata_updated(adata, results)
    adata_updated, results_df = run_colocalization(
        adata_updated, task_name_map=task_name_map, **kwargs
    )
    summary = summarise(adata_updated, results_df)
    return adata_updated, results_df, summary



def run_benchmark_per_sample(
    adata,
    results,
    task_name_map,
    sample_key="sample_id",
    **kwargs,
):
    """
    Run the colocalization benchmark separately for each sample, then merge
    the per-sample scores back into a single AnnData covering all cells.

    Parameters
    ----------
    adata : AnnData
        Full gene expression + spatial AnnData (all samples).
    results : scCellFie pipeline output
    task_name_map : dict
        Confirmed task names from inspect_task_names().
    sample_key : str
        Column in adata.obs that identifies each sample (default: 'sample_id').
    **kwargs
        Passed to run_colocalization() (neighbors_radius, method, etc.).

    Returns
    -------
    adata_updated : AnnData
        Full AnnData with colocalization scores in .obs for every cell.
    all_results : dict[str, pd.DataFrame]
        Per-sample results DataFrames keyed by sample name.
    all_summaries : dict[str, pd.DataFrame]
        Per-sample summary tables keyed by sample name.
    """
    if sample_key not in adata.obs.columns:
        raise ValueError(f"'{sample_key}' not found in adata.obs.columns.")

    samples = adata.obs[sample_key].unique()
    print(f"Found {len(samples)} samples: {list(samples)}\n")

    # Build the full merged AnnData first (gene expression + task scores)
    adata_updated_full = build_adata_updated(adata, results)

    # Collect scored obs columns across samples to pre-allocate NaN columns
    all_results  = {}
    all_summaries = {}
    scored_cols_global = set()

    per_sample_obs = {}  # sample -> obs DataFrame with scores

    for sample in samples:
        print(f"{'='*60}")
        print(f"Sample: {sample!r}")
        print(f"{'='*60}")

        # Slice to this sample only
        mask = adata_updated_full.obs[sample_key] == sample
        adata_sample = adata_updated_full[mask].copy()

        # Run colocalization on the sample slice
        adata_sample, results_df = run_colocalization(
            adata_sample,
            task_name_map=task_name_map,
            **kwargs,
        )

        scored_cols = results_df.columns.tolist()
        scored_cols_global.update(scored_cols)

        # Store per-sample results and summary
        all_results[sample]   = results_df
        all_summaries[sample] = summarise(adata_sample, results_df)

        # Keep the scored obs rows indexed by cell barcode
        per_sample_obs[sample] = adata_sample.obs[scored_cols]
        print()

    # --- Merge scores back into the full AnnData ---
    scored_cols_global = sorted(scored_cols_global)

    # Initialise all score columns as NaN
    for col in scored_cols_global:
        adata_updated_full.obs[col] = np.nan

    # Fill in per-sample scores using the cell index
    for sample, obs_df in per_sample_obs.items():
        adata_updated_full.obs.loc[obs_df.index, obs_df.columns] = obs_df.values

    print(f"{'='*60}")
    print(f"Done. Scores merged for {len(samples)} samples.")
    print(f"Scored columns in adata_updated.obs: {scored_cols_global}")

    return adata_updated_full, all_results, all_summaries

# %%
adata_updated, all_results, all_summaries = run_benchmark_per_sample(
    adata, results, task_name_map=None,
    sample_key="sample",          # <-- adjust to your column name
    neighbors_radius=550,
    method="pairwise_concordance",
    min_neighbors=3,
    spatial_key="spatial",
)
# Out:
# Found 14 samples: ['J38_T', 'Y7_T', 'S15_T', 'Y12_T', 'R_med', 'R51_T', 'R114_T', 'X49_T', 'X98_T', 'R_cor', 'R29_T', 'Z43_T', 'H46_T', 'Y27_T']
#
# adata_updated: 46398 cells × 36819 vars (36601 genes + 218 tasks)
# ============================================================
# Sample: 'J38_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (2916 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (2916 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (2916 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (2916 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (2916 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (2916 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (2916 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (2916 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (2916 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (2916 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (2916 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               2916      0.0296        0.0000     0.0581
# thromboxane__TBXA2R            2916      0.0207        0.0000     0.0461
# E2__ESR1                       2916      0.0112        0.0000     0.0341
# dopamine__DRD4                 2916      0.0099        0.0000     0.0411
# dopamine__DRD2                 2916      0.0008        0.0000     0.0096
# E2__ESR2                       2916      0.0003        0.0000     0.0051
# GABA__GABRA1                   2916      0.0000        0.0000     0.0000
# dopamine__DRD1                 2916      0.0000        0.0000     0.0000
# GABA__GABRG2                   2916      0.0000        0.0000     0.0000
# dopamine__DRD3                 2916      0.0000        0.0000     0.0000
# dopamine__DRD5                 2916      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'Y7_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (2016 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (2016 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (2016 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (2016 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (2016 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (2016 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (2016 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (2016 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (2016 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (2016 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (2016 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               2016      0.0701        0.0408     0.0927
# thromboxane__TBXA2R            2016      0.0384        0.0000     0.0609
# E2__ESR1                       2016      0.0173        0.0000     0.0424
# dopamine__DRD4                 2016      0.0141        0.0000     0.0366
# E2__ESR2                       2016      0.0007        0.0000     0.0076
# dopamine__DRD1                 2016      0.0005        0.0000     0.0068
# dopamine__DRD2                 2016      0.0004        0.0000     0.0042
# GABA__GABRA1                   2016      0.0000        0.0000     0.0000
# GABA__GABRG2                   2016      0.0000        0.0000     0.0000
# dopamine__DRD3                 2016      0.0000        0.0000     0.0000
# dopamine__DRD5                 2016      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'S15_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (2838 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (2838 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (2838 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (2838 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (2838 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (2838 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (2838 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (2838 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (2838 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (2838 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (2838 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               2838      0.0747        0.0612     0.0846
# thromboxane__TBXA2R            2838      0.0475        0.0408     0.0597
# E2__ESR1                       2838      0.0172        0.0000     0.0387
# dopamine__DRD4                 2838      0.0165        0.0000     0.0461
# dopamine__DRD1                 2838      0.0016        0.0000     0.0105
# GABA__GABRA1                   2838      0.0004        0.0000     0.0036
# E2__ESR2                       2838      0.0002        0.0000     0.0058
# dopamine__DRD2                 2838      0.0002        0.0000     0.0041
# GABA__GABRG2                   2838      0.0000        0.0000     0.0000
# dopamine__DRD3                 2838      0.0000        0.0000     0.0000
# dopamine__DRD5                 2838      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'Y12_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (1701 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (1701 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (1701 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (1701 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (1701 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (1701 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (1701 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (1701 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (1701 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (1701 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (1701 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               1701      0.0187        0.0000     0.0409
# thromboxane__TBXA2R            1701      0.0170        0.0000     0.0362
# E2__ESR1                       1701      0.0076        0.0000     0.0289
# dopamine__DRD4                 1701      0.0008        0.0000     0.0062
# E2__ESR2                       1701      0.0007        0.0000     0.0087
# GABA__GABRG2                   1701      0.0000        0.0000     0.0000
# GABA__GABRA1                   1701      0.0000        0.0000     0.0000
# dopamine__DRD1                 1701      0.0000        0.0000     0.0000
# dopamine__DRD2                 1701      0.0000        0.0000     0.0000
# dopamine__DRD3                 1701      0.0000        0.0000     0.0000
# dopamine__DRD5                 1701      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'R_med'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (4599 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (4599 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (4599 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (4599 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (4599 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (4599 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (4599 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (4599 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (4599 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (4599 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (4599 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               4599      0.0256        0.0000     0.0556
# E2__ESR1                       4599      0.0137        0.0000     0.0381
# thromboxane__TBXA2R            4599      0.0107        0.0000     0.0352
# E2__ESR2                       4599      0.0017        0.0000     0.0123
# dopamine__DRD4                 4599      0.0017        0.0000     0.0096
# dopamine__DRD1                 4599      0.0010        0.0000     0.0074
# GABA__GABRG2                   4599      0.0000        0.0000     0.0000
# GABA__GABRA1                   4599      0.0000        0.0000     0.0000
# dopamine__DRD2                 4599      0.0000        0.0000     0.0000
# dopamine__DRD3                 4599      0.0000        0.0000     0.0000
# dopamine__DRD5                 4599      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'R51_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (3017 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (3017 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (3017 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (3017 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (3017 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (3017 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (3017 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (3017 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (3017 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (3017 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (3017 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# thromboxane__TBXA2R            3017      0.0085        0.0000     0.0269
# E2__ESR1                       3017      0.0018        0.0000     0.0128
# testosterone__AR               3017      0.0011        0.0000     0.0097
# E2__ESR2                       3017      0.0007        0.0000     0.0073
# dopamine__DRD4                 3017      0.0002        0.0000     0.0019
# dopamine__DRD1                 3017      0.0000        0.0000     0.0011
# GABA__GABRG2                   3017      0.0000        0.0000     0.0000
# GABA__GABRA1                   3017      0.0000        0.0000     0.0000
# dopamine__DRD2                 3017      0.0000        0.0000     0.0000
# dopamine__DRD3                 3017      0.0000        0.0000     0.0000
# dopamine__DRD5                 3017      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'R114_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (2229 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (2229 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (2229 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (2229 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (2229 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (2229 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (2229 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (2229 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (2229 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (2229 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (2229 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               2229      0.0514        0.0000     0.0868
# dopamine__DRD4                 2229      0.0204        0.0000     0.0487
# thromboxane__TBXA2R            2229      0.0179        0.0000     0.0386
# E2__ESR1                       2229      0.0160        0.0000     0.0446
# GABA__GABRG2                   2229      0.0000        0.0000     0.0011
# E2__ESR2                       2229      0.0000        0.0000     0.0000
# GABA__GABRA1                   2229      0.0000        0.0000     0.0000
# dopamine__DRD1                 2229      0.0000        0.0000     0.0000
# dopamine__DRD2                 2229      0.0000        0.0000     0.0000
# dopamine__DRD3                 2229      0.0000        0.0000     0.0000
# dopamine__DRD5                 2229      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'X49_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (3052 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (3052 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (3052 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (3052 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (3052 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (3052 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (3052 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (3052 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (3052 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (3052 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (3052 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               3052      0.0252        0.0000     0.0506
# dopamine__DRD4                 3052      0.0103        0.0000     0.0332
# thromboxane__TBXA2R            3052      0.0084        0.0000     0.0232
# E2__ESR1                       3052      0.0054        0.0000     0.0230
# GABA__GABRG2                   3052      0.0002        0.0000     0.0031
# E2__ESR2                       3052      0.0002        0.0000     0.0045
# dopamine__DRD1                 3052      0.0002        0.0000     0.0037
# GABA__GABRA1                   3052      0.0000        0.0000     0.0000
# dopamine__DRD2                 3052      0.0000        0.0000     0.0000
# dopamine__DRD3                 3052      0.0000        0.0000     0.0000
# dopamine__DRD5                 3052      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'X98_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (4982 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (4982 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (4982 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (4982 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (4982 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (4982 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (4982 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (4982 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (4982 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (4982 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (4982 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               4982      0.0180        0.0000     0.0498
# thromboxane__TBXA2R            4982      0.0052        0.0000     0.0222
# E2__ESR1                       4982      0.0019        0.0000     0.0142
# E2__ESR2                       4982      0.0004        0.0000     0.0064
# dopamine__DRD4                 4982      0.0004        0.0000     0.0050
# dopamine__DRD1                 4982      0.0001        0.0000     0.0019
# GABA__GABRG2                   4982      0.0000        0.0000     0.0006
# GABA__GABRA1                   4982      0.0000        0.0000     0.0000
# dopamine__DRD2                 4982      0.0000        0.0000     0.0000
# dopamine__DRD3                 4982      0.0000        0.0000     0.0000
# dopamine__DRD5                 4982      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'R_cor'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (4167 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (4167 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (4167 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (4167 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (4167 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (4167 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (4167 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (4167 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (4167 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (4167 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (4167 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               4167      0.0062        0.0000     0.0210
# E2__ESR1                       4167      0.0048        0.0000     0.0210
# thromboxane__TBXA2R            4167      0.0039        0.0000     0.0155
# dopamine__DRD4                 4167      0.0010        0.0000     0.0072
# dopamine__DRD1                 4167      0.0006        0.0000     0.0054
# E2__ESR2                       4167      0.0002        0.0000     0.0038
# GABA__GABRG2                   4167      0.0001        0.0000     0.0020
# dopamine__DRD2                 4167      0.0000        0.0000     0.0010
# GABA__GABRA1                   4167      0.0000        0.0000     0.0000
# dopamine__DRD3                 4167      0.0000        0.0000     0.0000
# dopamine__DRD5                 4167      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'R29_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (4324 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (4324 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (4324 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (4324 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (4324 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (4324 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (4324 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (4324 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (4324 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (4324 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (4324 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               4324      0.0497        0.0204     0.0666
# thromboxane__TBXA2R            4324      0.0064        0.0000     0.0226
# E2__ESR1                       4324      0.0037        0.0000     0.0168
# dopamine__DRD4                 4324      0.0037        0.0000     0.0171
# dopamine__DRD1                 4324      0.0003        0.0000     0.0045
# GABA__GABRG2                   4324      0.0001        0.0000     0.0029
# E2__ESR2                       4324      0.0001        0.0000     0.0021
# GABA__GABRA1                   4324      0.0000        0.0000     0.0000
# dopamine__DRD2                 4324      0.0000        0.0000     0.0000
# dopamine__DRD3                 4324      0.0000        0.0000     0.0000
# dopamine__DRD5                 4324      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'Z43_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (3695 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (3695 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (3695 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (3695 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (3695 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (3695 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (3695 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (3695 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (3695 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (3695 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (3695 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               3695      0.0355        0.0000     0.0567
# thromboxane__TBXA2R            3695      0.0226        0.0000     0.0460
# E2__ESR1                       3695      0.0091        0.0000     0.0284
# dopamine__DRD4                 3695      0.0039        0.0000     0.0173
# dopamine__DRD1                 3695      0.0011        0.0000     0.0103
# E2__ESR2                       3695      0.0001        0.0000     0.0035
# dopamine__DRD2                 3695      0.0001        0.0000     0.0013
# GABA__GABRA1                   3695      0.0000        0.0000     0.0000
# GABA__GABRG2                   3695      0.0000        0.0000     0.0000
# dopamine__DRD3                 3695      0.0000        0.0000     0.0000
# dopamine__DRD5                 3695      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'H46_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (3697 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (3697 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (3697 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (3697 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (3697 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (3697 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (3697 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (3697 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (3697 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (3697 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (3697 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# thromboxane__TBXA2R            3697      0.0274        0.0000     0.0552
# testosterone__AR               3697      0.0112        0.0000     0.0318
# E2__ESR1                       3697      0.0040        0.0000     0.0175
# GABA__GABRG2                   3697      0.0002        0.0000     0.0038
# E2__ESR2                       3697      0.0001        0.0000     0.0028
# dopamine__DRD4                 3697      0.0001        0.0000     0.0018
# dopamine__DRD1                 3697      0.0000        0.0000     0.0011
# GABA__GABRA1                   3697      0.0000        0.0000     0.0007
# dopamine__DRD2                 3697      0.0000        0.0000     0.0000
# dopamine__DRD3                 3697      0.0000        0.0000     0.0000
# dopamine__DRD5                 3697      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Sample: 'Y27_T'
# ============================================================
#   Scoring  'E2__ESR1'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR1'] ...  done  (3046 cells scored)
#   Scoring  'E2__ESR2'  |  'Synthesis of estradiol-17beta (E2) from androstenedione'  →  ['ESR2'] ...  done  (3046 cells scored)
#   Scoring  'thromboxane__TBXA2R'  |  'Synthesis of thromboxane from arachidonate'  →  ['TBXA2R'] ...  done  (3046 cells scored)
#   Scoring  'GABA__GABRA1'  |  'Synthesis of GABA'  →  ['GABRA1'] ...  done  (3046 cells scored)
#   Scoring  'GABA__GABRG2'  |  'Synthesis of GABA'  →  ['GABRG2'] ...  done  (3046 cells scored)
#   Scoring  'testosterone__AR'  |  'Synthesis of testosterone from androstenedione'  →  ['AR'] ...  done  (3046 cells scored)
#   Scoring  'dopamine__DRD1'  |  'Tyrosine to dopamine'  →  ['DRD1'] ...  done  (3046 cells scored)
#   Scoring  'dopamine__DRD2'  |  'Tyrosine to dopamine'  →  ['DRD2'] ...  done  (3046 cells scored)
#   Scoring  'dopamine__DRD3'  |  'Tyrosine to dopamine'  →  ['DRD3'] ...  done  (3046 cells scored)
#   Scoring  'dopamine__DRD4'  |  'Tyrosine to dopamine'  →  ['DRD4'] ...  done  (3046 cells scored)
#   Scoring  'dopamine__DRD5'  |  'Tyrosine to dopamine'  →  ['DRD5'] ...  done  (3046 cells scored)
#   → 11/11 pairs scored successfully.
#
# ============================================================
# Colocalization score summary
# ============================================================
#                      n_cells_scored  mean_score  median_score  std_score
# pair
# testosterone__AR               3046      0.0367        0.0000     0.0620
# thromboxane__TBXA2R            3046      0.0248        0.0000     0.0445
# E2__ESR1                       3046      0.0189        0.0000     0.0478
# dopamine__DRD4                 3046      0.0063        0.0000     0.0264
# dopamine__DRD1                 3046      0.0004        0.0000     0.0052
# E2__ESR2                       3046      0.0002        0.0000     0.0036
# dopamine__DRD2                 3046      0.0001        0.0000     0.0022
# GABA__GABRA1                   3046      0.0000        0.0000     0.0000
# GABA__GABRG2                   3046      0.0000        0.0000     0.0000
# dopamine__DRD3                 3046      0.0000        0.0000     0.0000
# dopamine__DRD5                 3046      0.0000        0.0000     0.0000
# ============================================================
#
# ============================================================
# Done. Scores merged for 14 samples.
# Scored columns in adata_updated.obs: ['E2__ESR1', 'E2__ESR2', 'GABA__GABRA1', 'GABA__GABRG2', 'dopamine__DRD1', 'dopamine__DRD2', 'dopamine__DRD3', 'dopamine__DRD4', 'dopamine__DRD5', 'testosterone__AR', 'thromboxane__TBXA2R']

# %%
# adata_updated.write(f"{ADATA_PATH}/Visium_RCC_CCC_scCellFie.h5ad")
